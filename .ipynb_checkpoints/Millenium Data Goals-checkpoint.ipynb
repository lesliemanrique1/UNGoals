# %% [markdown]
# # Millenium Development Goals Challenge

# %%
import numpy as np
import pandas as pd
#from sklearn import preprocessing
from sklearn.preprocessing import Imputer
import statsmodels.api as sm

# %%
training_data = pd.DataFrame.from_csv("data/TrainingSet.csv", index_col=0)

# %%
training_data.head()
# Out:
#    1972 [YR1972]  1973 [YR1973]  1974 [YR1974]  1975 [YR1975]  1976 [YR1976]  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
# 5            NaN            NaN            NaN            NaN            NaN
#
#    1977 [YR1977]  1978 [YR1978]  1979 [YR1979]  1980 [YR1980]  1981 [YR1981]  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
# 5            NaN            NaN            NaN            NaN            NaN
#
# ...

# %%
afgh = training_data[training_data["Country Name"] == "Afghanistan"]

# %%
usa = training_data[training_data["Country Name"] == "United States"]

# %%
usa.head()
# Out:
#         1972 [YR1972]  1973 [YR1973]  1974 [YR1974]  1975 [YR1975]  \
# 271423            NaN            NaN            NaN            NaN
# 271424            NaN            NaN            NaN            NaN
# 271427            NaN            NaN            NaN       0.807367
# 271428            NaN            NaN            NaN            NaN
# 271429            NaN            NaN            NaN            NaN
#
#         1976 [YR1976]  1977 [YR1977]  1978 [YR1978]  1979 [YR1979]  \
# 271423            NaN            NaN            NaN            NaN
# 271424            NaN            NaN            NaN            NaN
# 271427            NaN            NaN            NaN            NaN
# 271428            NaN            NaN            NaN            NaN
# 271429            NaN            NaN            NaN            NaN
#
#         1980 [YR1980]  1981 [YR1981]  \
# 271423            NaN            NaN
# 271424            NaN            NaN
# 271427            NaN            NaN
# ...

# %%
column_list = list(afgh.columns.values)

# %%
mylist = training_data["Series Name"].tolist();

# %%
mylist
# Out:
# ['(%) Benefits held by 1st 20% population - All Social Insurance',
#  '(%) Benefits held by 1st 20% population - All Social Protection',
#  '(%) Benefits held by 1st 20% population - All Social Safety Nets',
#  '(%) Generosity of All Social Insurance',
#  '(%) Generosity of All Social Protection',
#  '(%) Generosity of All Social Safety Nets',
#  '(%) Program participation - All Social Insurance',
#  '(%) Program participation - All Social Protection',
#  '(%) Program participation - All Social Safety Nets',
#  '(%) Program participation - Unemp benefits and ALMP',
#  '2005 PPP conversion factor, GDP (LCU per international $)',
#  '2005 PPP conversion factor, private consumption (LCU per international $)',
#  'Achieve universal primary education',
#  'Adjusted net enrollment rate, primary, female (% of primary school age children)',
#  'Adjusted net enrollment rate, primary, male (% of primary school age children)',
#  'Adjusted net national income (constant 2005 US$)',
# ...

# %%
len(mylist)
# Out:
# 195402

# %%
#list of unique series names in list
uniquelist = training_data["Series Name"].unique();

# %%
len(uniquelist)
# Out:
# 1305

# %%
#list of data frames by series name 
datalists = []
for val in uniquelist:
    newdf = training_data[training_data["Series Name"]==val] 
    datalists.append(newdf); 

# newdf = training_data[training_data["Series Name"]==uniquelist[0]] 
# datalists.append(newdf);

# %%
##missing values 
##what is the best way to handle missing values? 
##ignore , delete, replace?

# %%
#drop columns that are all na and rows that are all na 
# for data in datalists:
#     data = data.dropna(axis = 1, how = "all")
#     data = data.dropna(how="all")

# %%
datalists[100].tail()
# Out:
#         1972 [YR1972]  1973 [YR1973]  1974 [YR1974]  1975 [YR1975]  \
# 278235       5104.464       7356.002       8789.799      12189.108
# 280909            NaN            NaN            NaN            NaN
# 282246          0.000          0.000          0.000          0.000
# 283583       2339.546       2251.538       1987.514       1859.169
# 284920       6299.906       7190.987       6802.285       5874.534
#
#         1976 [YR1976]  1977 [YR1977]  1978 [YR1978]  1979 [YR1979]  \
# 278235      11400.703      12577.810      12134.103      12625.481
# 280909            NaN            NaN            NaN            NaN
# 282246          0.000          0.000          0.000          0.000
# 283583       1796.830       1591.478       1404.461       1342.122
# 284920       8947.480       7363.336       7389.005       7744.704
#
#         1980 [YR1980]  1981 [YR1981]  \
# 278235      12746.492      13278.207
# 280909            NaN            NaN
# 282246          0.000          0.000
# ...

# %%
datalists[100].isnull().sum()
# Out:
# 1972 [YR1972]    35
# 1973 [YR1973]    35
# 1974 [YR1974]    35
# 1975 [YR1975]    35
# 1976 [YR1976]    35
# 1977 [YR1977]    35
# 1978 [YR1978]    34
# 1979 [YR1979]    34
# 1980 [YR1980]    34
# 1981 [YR1981]    34
# 1982 [YR1982]    34
# 1983 [YR1983]    34
# 1984 [YR1984]    34
# 1985 [YR1985]    35
# 1986 [YR1986]    33
# 1987 [YR1987]    33
# 1988 [YR1988]    33
# 1989 [YR1989]    33
# 1990 [YR1990]    31
# 1991 [YR1991]    30
# 1992 [YR1992]     9
# 1993 [YR1993]     9
# 1994 [YR1994]     8
# 1995 [YR1995]     6
# 1996 [YR1996]     7
# 1997 [YR1997]     5
# 1998 [YR1998]     5
# 1999 [YR1999]     5
# 2000 [YR2000]     4
# 2001 [YR2001]     4
# 2002 [YR2002]     3
# 2003 [YR2003]     3
# 2004 [YR2004]     3
# 2005 [YR2005]     2
# 2006 [YR2006]     1
# 2007 [YR2007]     0
# Country Name      0
# Series Code       0
# Series Name       0
# dtype: int64

# %%
### how about a constant? 
### lets pick 0 first

# %%
### plot missing value data

# %%
### machine learning algorithm to predict year (naive bayes?)
### which way to handle missing values gives us the best accuracy ?
