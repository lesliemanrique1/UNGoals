# %% [markdown]
# # Millenium Development Goals Challenge

# %%
import numpy as np
import pandas as pd
#from sklearn import preprocessing
from sklearn.preprocessing import Imputer
import statsmodels.api as sm

# %%
training_data = pd.DataFrame.from_csv("data/TrainingSet.csv", index_col=0)

# %%
training_data.head()
# Out:
#    1972 [YR1972]  1973 [YR1973]  1974 [YR1974]  1975 [YR1975]  1976 [YR1976]  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
# 5            NaN            NaN            NaN            NaN            NaN
#
#    1977 [YR1977]  1978 [YR1978]  1979 [YR1979]  1980 [YR1980]  1981 [YR1981]  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
# 5            NaN            NaN            NaN            NaN            NaN
#
# ...

# %%
afgh = training_data[training_data["Country Name"] == "Afghanistan"]

# %%
usa = training_data[training_data["Country Name"] == "United States"]

# %%
usa.head()
# Out:
#         1972 [YR1972]  1973 [YR1973]  1974 [YR1974]  1975 [YR1975]  \
# 271423            NaN            NaN            NaN            NaN
# 271424            NaN            NaN            NaN            NaN
# 271427            NaN            NaN            NaN       0.807367
# 271428            NaN            NaN            NaN            NaN
# 271429            NaN            NaN            NaN            NaN
#
#         1976 [YR1976]  1977 [YR1977]  1978 [YR1978]  1979 [YR1979]  \
# 271423            NaN            NaN            NaN            NaN
# 271424            NaN            NaN            NaN            NaN
# 271427            NaN            NaN            NaN            NaN
# 271428            NaN            NaN            NaN            NaN
# 271429            NaN            NaN            NaN            NaN
#
#         1980 [YR1980]  1981 [YR1981]  \
# 271423            NaN            NaN
# 271424            NaN            NaN
# 271427            NaN            NaN
# ...

# %%
column_list = list(afgh.columns.values)

# %%
mylist = training_data["Series Name"].tolist();

# %%
#mylist

# %%
len(mylist)
# Out:
# 195402

# %%
#list of unique series names in list
uniquelist = training_data["Series Name"].unique();

# %%
len(uniquelist)
# Out:
# 1305

# %%
#list of data frames by series name 
datalists = []
for val in uniquelist:
    newdf = training_data[training_data["Series Name"]==val] 
    datalists.append(newdf); 

# newdf = training_data[training_data["Series Name"]==uniquelist[0]] 
# datalists.append(newdf);

# %%
##missing values 
##what is the best way to handle missing values? 
##ignore , delete, replace?

# %%
#drop columns that are all na and rows that are all na 
# for data in datalists:
#     data = data.dropna(axis = 1, how = "all")
#     data = data.dropna(how="all")

# %%
datalists[100].tail()
# Out:
#         1972 [YR1972]  1973 [YR1973]  1974 [YR1974]  1975 [YR1975]  \
# 278235       5104.464       7356.002       8789.799      12189.108
# 280909            NaN            NaN            NaN            NaN
# 282246          0.000          0.000          0.000          0.000
# 283583       2339.546       2251.538       1987.514       1859.169
# 284920       6299.906       7190.987       6802.285       5874.534
#
#         1976 [YR1976]  1977 [YR1977]  1978 [YR1978]  1979 [YR1979]  \
# 278235      11400.703      12577.810      12134.103      12625.481
# 280909            NaN            NaN            NaN            NaN
# 282246          0.000          0.000          0.000          0.000
# 283583       1796.830       1591.478       1404.461       1342.122
# 284920       8947.480       7363.336       7389.005       7744.704
#
#         1980 [YR1980]  1981 [YR1981]  \
# 278235      12746.492      13278.207
# 280909            NaN            NaN
# 282246          0.000          0.000
# ...

# %%
datalists[100].isnull().sum()
# Out:
# 1972 [YR1972]    35
# 1973 [YR1973]    35
# 1974 [YR1974]    35
# 1975 [YR1975]    35
# 1976 [YR1976]    35
# 1977 [YR1977]    35
# 1978 [YR1978]    34
# 1979 [YR1979]    34
# 1980 [YR1980]    34
# 1981 [YR1981]    34
# 1982 [YR1982]    34
# 1983 [YR1983]    34
# 1984 [YR1984]    34
# 1985 [YR1985]    35
# 1986 [YR1986]    33
# 1987 [YR1987]    33
# 1988 [YR1988]    33
# 1989 [YR1989]    33
# 1990 [YR1990]    31
# 1991 [YR1991]    30
# 1992 [YR1992]     9
# 1993 [YR1993]     9
# 1994 [YR1994]     8
# 1995 [YR1995]     6
# 1996 [YR1996]     7
# 1997 [YR1997]     5
# 1998 [YR1998]     5
# 1999 [YR1999]     5
# 2000 [YR2000]     4
# 2001 [YR2001]     4
# 2002 [YR2002]     3
# 2003 [YR2003]     3
# 2004 [YR2004]     3
# 2005 [YR2005]     2
# 2006 [YR2006]     1
# 2007 [YR2007]     0
# Country Name      0
# Series Code       0
# Series Name       0
# dtype: int64

# %%
df = datalists[100]._get_numeric_data() #only look at numeric data... 
df
# Out:
#         1972 [YR1972]  1973 [YR1973]  1974 [YR1974]  1975 [YR1975]  \
# 139           190.684        311.695        304.361        399.703
# 1476         1081.765       1169.773       1210.110       1261.448
# 2813          649.059        821.408        700.397        792.072
# 5487              NaN            NaN            NaN            NaN
# 6824            7.334         22.002          0.000          0.000
# 8161            0.000          0.000          0.000          0.000
# 9498         2860.260       2882.262       3369.973       3597.327
# 10835             NaN            NaN            NaN            NaN
# 12172             NaN            NaN            NaN            NaN
# 13509       77799.072      79779.252      85272.418      87014.243
# 14846       15647.089      15867.109      16618.844      14576.325
# 16183             NaN            NaN            NaN            NaN
# 17520           0.000         14.668         11.001          0.000
# ...

# %%
#sci-kit learn mean value replacement
#replaces missing values with mean value in df 
imp = Imputer(missing_values='NaN', strategy='mean', axis=0)
imp.fit(df)
transformed = imp.transform(df)

# %%
transformed
# Out:
# array([[  190.684,   311.695,   304.361, ...,   106.343,   161.348,
#           748.068],
#        [ 1081.765,  1169.773,  1210.11 , ...,    73.34 ,    73.34 ,
#            73.34 ],
#        [  649.059,   821.408,   700.397, ...,  2442.222,  2555.899,
#          2907.931],
#        ...,
#        [    0.   ,     0.   ,     0.   , ...,     0.   ,     0.   ,     0.   ],
#        [ 2339.546,  2251.538,  1987.514, ...,   311.695,   128.345,
#            33.003],
#        [ 6299.906,  7190.987,  6802.285, ...,  8489.105,  8082.068,
#          8096.736]])

# %%
## plot data

# %%
## test accuracy of missing value handling
